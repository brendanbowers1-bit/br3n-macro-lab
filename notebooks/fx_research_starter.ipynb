# %% [markdown]
# # BR3N FX Research Terminal — Starter Notebook
#
# Research only. Not investment advice.
#
# Run cells to load data, build features, and compare baseline models.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.data.pipeline import build_terminal_data_bundle
from src.features.fx_terminal_features import build_multi_pair_feature_table
from src.backtesting.walk_forward import run_model_comparison
from src.data.constants import CORE_FX_PAIRS

# %%
bundle = build_terminal_data_bundle(use_mock_on_failure=True)
features = build_multi_pair_feature_table(
    bundle.market, bundle.macro, bundle.rates, bundle.sentiment,
    pairs=CORE_FX_PAIRS[:3],
)
features.tail()

# %%
signals, comparison = run_model_comparison(features, pairs=CORE_FX_PAIRS[:2], horizon=5)
comparison
